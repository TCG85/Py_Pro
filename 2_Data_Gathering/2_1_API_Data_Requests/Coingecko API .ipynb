# %% [markdown]
# # Importing needed libraries

# %%
import pandas as pd
import requests
import json
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# # Importing list of coins

# %%
base = 'https://api.coingecko.com/api/v3/'
url = base + 'coins/list'

# %%
result = requests.get(url)
result
# Out:
# <Response [200]>

# %%
j = result.json()
j
# Out:
# [{'id': 'bitcoin', 'symbol': 'btc', 'name': 'Bitcoin'},
#  {'id': 'litecoin', 'symbol': 'ltc', 'name': 'Litecoin'},
#  {'id': 'auroracoin', 'symbol': 'aur', 'name': 'Auroracoin'},
#  {'id': 'peercoin', 'symbol': 'ppc', 'name': 'Peercoin'},
#  {'id': 'dogecoin', 'symbol': 'doge', 'name': 'Dogecoin'},
#  {'id': 'nxt', 'symbol': 'nxt', 'name': 'NXT'},
#  {'id': 'omni', 'symbol': 'omni', 'name': 'Omni'},
#  {'id': 'namecoin', 'symbol': 'nmc', 'name': 'Namecoin'},
#  {'id': 'counterparty', 'symbol': 'xcp', 'name': 'Counterparty'},
#  {'id': 'quark', 'symbol': 'qrk', 'name': 'Quark'},
#  {'id': 'feathercoin', 'symbol': 'ftc', 'name': 'Feathercoin'},
#  {'id': 'primecoin', 'symbol': 'xpm', 'name': 'Primecoin'},
#  {'id': 'infinitecoin', 'symbol': 'ifc', 'name': 'Infinitecoin'},
#  {'id': 'novacoin', 'symbol': 'nvc', 'name': 'Novacoin'},
#  {'id': 'megacoin', 'symbol': 'mec', 'name': 'Megacoin'},
#  {'id': 'worldcoin', 'symbol': 'wdc', 'name': 'Worldcoin'},
#  {'id': 'vertcoin', 'symbol': 'vtc', 'name': 'Vertcoin'},
#  {'id': 'dash', 'symbol': 'dash', 'name': 'Dash'},
#  {'id': 'ybcoin', 'symbol': 'ybct', 'name': 'Ybcoin'},
#  {'id': 'mintcoin', 'symbol': 'mint', 'name': 'Mintcoin'},
#  {'id': 'devcoin', 'symbol': 'dvc', 'name': 'Devcoin'},
#  {'id': 'anoncoin', 'symbol': 'anc', 'name': 'Anoncoin'},
#  {'id': 'maxcoin', 'symbol': 'max', 'name': 'Maxcoin'},
#  {'id': 'ultracoin', 'symbol': 'utc', 'name': 'Ultracoin'},
#  {'id': 'zetacoin', 'symbol': 'zet', 'name': 'Zetacoin'},
#  {'id': 'cachecoin', 'symbol': 'cach', 'name': 'Cachecoin'},
#  {'id': 'ixcoin', 'symbol': 'ixc', 'name': 'Ixcoin'},
#  {'id': 'freicoin', 'symbol': 'frc', 'name': 'Freicoin'},
#  {'id': 'terracoin', 'symbol': 'trc', 'name': 'Terracoin'},
#  {'id': 'copperlark', 'symbol': 'clr', 'name': 'Copperlark'},
#  {'id': 'digitalcoin', 'symbol': 'dgc', 'name': 'Digitalcoin'},
#  {'id': 'fedoracoin', 'symbol': 'tips', 'name': 'Fedoracoin'},
#  {'id': 'netcoin', 'symbol': 'net', 'name': 'Netcoin'},
#  {'id': 'unobtanium', 'symbol': 'uno', 'name': 'Unobtanium'},
#  {'id': 'reddcoin', 'symbol': 'rdd', 'name': 'Reddcoin'},
#  {'id': 'ripple', 'symbol': 'xrp', 'name': 'XRP'},
#  {'id': 'einsteinium', 'symbol': 'emc2', 'name': 'Einsteinium'},
#  {'id': 'goldcoin', 'symbol': 'gld', 'name': 'Goldcoin'},
#  {'id': 'blackcoin', 'symbol': 'blk', 'name': 'BlackCoin'},
#  {'id': 'potcoin', 'symbol': 'pot', 'name': 'Potcoin'},
#  {'id': 'fluttercoin', 'symbol': 'flt', 'name': 'Fluttercoin'},
#  {'id': 'usde', 'symbol': 'usde', 'name': 'USDe'},
#  {'id': 'hobonickels', 'symbol': 'hbn', 'name': 'Hobonickels'},
#  {'id': 'whitecoin', 'symbol': 'xwc', 'name': 'Whitecoin'},
#  {'id': 'digibyte', 'symbol': 'dgb', 'name': 'DigiByte'},
#  {'id': 'casinocoin', 'symbol': 'csc', 'name': 'Casinocoin'},
#  {'id': 'zeitcoin', 'symbol': 'zeit', 'name': 'Zeitcoin'},
#  {'id': 'myriadcoin', 'symbol': 'xmy', 'name': 'Myriad'},
#  {'id': 'monero', 'symbol': 'xmr', 'name': 'Monero'},
#  {'id': 'groestlcoin', 'symbol': 'grs', 'name': 'Groestlcoin'},
#  {'id': 'asiacoin', 'symbol': 'ac', 'name': 'Asiacoin'},
#  {'id': 'globalboost', 'symbol': 'bsty', 'name': 'GlobalBoost-Y'},
#  {'id': 'curecoin', 'symbol': 'cure', 'name': 'Curecoin'},
#  {'id': 'xcurrency', 'symbol': 'xc', 'name': 'XCurrency'},
#  {'id': 'vericoin', 'symbol': 'vrc', 'name': 'VeriCoin'},
#  {'id': 'cryptcoin', 'symbol': 'crypt', 'name': 'CryptCoin'},
#  {'id': 'maidsafecoin', 'symbol': 'maid', 'name': 'MaidSafeCoin'},
#  {'id': 'cloakcoin', 'symbol': 'cloak', 'name': 'Cloakcoin'},
#  {'id': 'dnotes', 'symbol': 'note', 'name': 'DNotes'},
#  {'id': 'karma', 'symbol': 'krm', 'name': 'Karma'},
#  {'id': 'bytecoin', 'symbol': 'bcn', 'name': 'Bytecoin'},
#  {'id': 'bitshares', 'symbol': 'bts', 'name': 'BitShares'},
#  {'id': 'bluecoin', 'symbol': 'blu', 'name': 'Bluecoin'},
#  {'id': 'bitbar', 'symbol': 'btb', 'name': 'Bitbar'},
#  {'id': 'mincoin', 'symbol': 'mnc', 'name': 'Mincoin'},
#  {'id': 'monacoin', 'symbol': 'mona', 'name': 'MonaCoin'},
#  {'id': 'stellar', 'symbol': 'xlm', 'name': 'Stellar'},
#  {'id': 'virtacoinplus', 'symbol': 'xvp', 'name': 'Virtacoinplus'},
#  {'id': 'pinkcoin', 'symbol': 'pink', 'name': 'Pinkcoin'},
#  {'id': 'iocoin', 'symbol': 'ioc', 'name': 'I/O Coin'},
#  {'id': 'cannabiscoin', 'symbol': 'cann', 'name': 'CannabisCoin'},
#  {'id': 'earthcoin', 'symbol': 'eac', 'name': 'Earthcoin'},
#  {'id': 'viacoin', 'symbol': 'via', 'name': 'Viacoin'},
#  {'id': 'syscoin', 'symbol': 'sys', 'name': 'Syscoin'},
#  {'id': 'boolberry', 'symbol': 'bbr', 'name': 'Boolberry'},
#  {'id': 'bitmark', 'symbol': 'marks', 'name': 'Bitmark'},
#  {'id': 'huntercoin', 'symbol': 'huc', 'name': 'Huntercoin'},
#  {'id': 'startcoin', 'symbol': 'start', 'name': 'Startcoin'},
#  {'id': 'sync', 'symbol': 'sync', 'name': 'Sync'},
#  {'id': 'hyperstake', 'symbol': 'hyp', 'name': 'HyperStake'},
#  {'id': 'digitalnote', 'symbol': 'xdn', 'name': 'DigitalNote'},
#  {'id': 'bullion', 'symbol': 'cbx', 'name': 'Bullion'},
#  {'id': 'cryptoescudo', 'symbol': 'cesc', 'name': 'CryptoEscudo'},
#  {'id': 'bitstar', 'symbol': 'bits', 'name': 'Bitstar'},
#  {'id': 'opal', 'symbol': 'opal', 'name': 'Opal'},
#  {'id': 'pandacoin', 'symbol': 'pnd', 'name': 'Pandacoin'},
#  {'id': 'artbyte', 'symbol': 'aby', 'name': 'ArtByte'},
#  {'id': 'hyper', 'symbol': 'hyper', 'name': 'Hyper'},
#  {'id': 'gulden', 'symbol': 'nlg', 'name': 'Gulden'},
#  {'id': 'rubycoin', 'symbol': 'rby', 'name': 'Rubycoin'},
#  {'id': 'neoscoin', 'symbol': 'neos', 'name': 'Neoscoin'},
#  {'id': 'solarcoin', 'symbol': 'slr', 'name': 'Solarcoin'},
#  {'id': 'burst', 'symbol': 'burst', 'name': 'Burst'},
#  {'id': 'cannacoin', 'symbol': 'ccn', 'name': 'Cannacoin'},
#  {'id': 'cryptonite', 'symbol': 'xcn', 'name': 'Cryptonite'},
#  {'id': 'sexcoin', 'symbol': 'sxc', 'name': 'Sexcoin'},
#  {'id': 'diamond', 'symbol': 'dmd', 'name': 'Diamond'},
#  {'id': 'nubits', 'symbol': 'usnbt', 'name': 'NuBits'},
#  {'id': 'supernet', 'symbol': 'unity', 'name': 'SuperNET'},
#  {'id': 'monetaryunit', 'symbol': 'mue', 'name': 'MonetaryUnit'},
#  {'id': 'nushares', 'symbol': 'nsr', 'name': 'NuShares'},
#  {'id': 'acoin', 'symbol': 'acoin', 'name': 'Acoin'},
#  {'id': 'fastcoin', 'symbol': 'fst', 'name': 'Fastcoin'},
#  {'id': 'magi', 'symbol': 'xmg', 'name': 'Magi'},
#  {'id': 'phoenixcoin', 'symbol': 'pxc', 'name': 'Phoenixcoin'},
#  {'id': 'ufocoin', 'symbol': 'ufo', 'name': 'Uniform Fiscal Object'},
#  {'id': 'bottlecaps', 'symbol': 'cap', 'name': 'Bottlecaps'},
#  {'id': 'ubiq', 'symbol': 'ubq', 'name': 'Ubiq'},
#  {'id': 'node', 'symbol': 'node', 'name': 'Node'},
#  {'id': 'fuelcoin', 'symbol': 'fc2', 'name': 'FuelCoin'},
#  {'id': 'glowshares', 'symbol': 'gsx', 'name': 'GlowShares'},
#  {'id': 'stealthcoin', 'symbol': 'xst', 'name': 'Stealth'},
#  {'id': 'piggycoin', 'symbol': 'piggy', 'name': 'Piggycoin'},
#  {'id': 'fantomcoin', 'symbol': 'fcn', 'name': 'Fantomcoin'},
#  {'id': 'gamecredits', 'symbol': 'game', 'name': 'GameCredits'},
#  {'id': 'paycoin', 'symbol': 'xpy', 'name': 'Paycoin'},
#  {'id': 'swarm', 'symbol': 'swm', 'name': 'Swarm Fund'},
#  {'id': 'bytecent', 'symbol': 'byc', 'name': 'Bytecent'},
#  {'id': 'supercoin', 'symbol': 'super', 'name': 'SuperCoin'},
#  {'id': 'spreadcoin', 'symbol': 'spr', 'name': 'SpreadCoin'},
#  {'id': 'bunnycoin', 'symbol': 'bun', 'name': 'Bunnycoin'},
#  {'id': 'verge', 'symbol': 'xvg', 'name': 'Verge'},
#  {'id': 'noblecoin', 'symbol': 'nobl', 'name': 'NobleCoin'},
#  {'id': 'sterlingcoin', 'symbol': 'slg', 'name': 'Sterlingcoin'},
#  {'id': 'clams', 'symbol': 'clam', 'name': 'Clams'},
#  {'id': 'bitstake', 'symbol': 'xbs', 'name': 'BitStake'},
#  {'id': 'tittiecoin', 'symbol': 'ttc', 'name': 'TittieCoin'},
#  {'id': 'nav-coin', 'symbol': 'nav', 'name': 'NavCoin'},
#  {'id': 'electronicgulden', 'symbol': 'efl', 'name': 'Electronic Gulden'},
#  {'id': 'blocknet', 'symbol': 'block', 'name': 'Blocknet'},
#  {'id': 'bitusd', 'symbol': 'bitusd', 'name': 'BitUSD'},
#  {'id': 'flo', 'symbol': 'flo', 'name': 'FLO'},
#  {'id': 'nem', 'symbol': 'xem', 'name': 'NEM'},
#  {'id': 'gridcoin-research', 'symbol': 'grc', 'name': 'Gridcoin'},
#  {'id': 'blakecoin', 'symbol': 'blc', 'name': 'Blakecoin'},
#  {'id': 'gsmcoin', 'symbol': 'gsm', 'name': 'GSMcoin'},
#  {'id': 'xcoin', 'symbol': 'xco', 'name': 'X-Coin'},
#  {'id': 'trollcoin', 'symbol': 'troll', 'name': 'Trollcoin'},
#  {'id': 'bitz', 'symbol': 'bitz', 'name': 'Bitz'},
#  {'id': 'bitswift', 'symbol': 'bits', 'name': 'Bitswift'},
#  {'id': 'crave', 'symbol': 'crave', 'name': 'Crave'},
#  {'id': 'bean-cash', 'symbol': 'bitb', 'name': 'Bean Cash'},
#  {'id': 'faircoin', 'symbol': 'fair', 'name': 'Faircoin'},
#  {'id': 'litedoge', 'symbol': 'ldoge', 'name': 'LiteDoge'},
#  {'id': 'bitbay', 'symbol': 'bay', 'name': 'BitBay'},
#  {'id': 'emercoin', 'symbol': 'emc', 'name': 'EmerCoin'},
#  {'id': 'orbitcoin', 'symbol': 'orb', 'name': 'Orbitcoin'},
#  {'id': 'quatloo', 'symbol': 'qtl', 'name': 'Quatloo'},
#  {'id': 'ucoin', 'symbol': 'u', 'name': 'Ucoin'},
#  {'id': 'cerium', 'symbol': 'xce', 'name': 'Cerium'},
#  {'id': 'quazarcoin', 'symbol': 'qcn', 'name': 'QuazarCoin'},
#  {'id': 'vpncoin', 'symbol': 'vash', 'name': 'VPNCoin'},
#  {'id': 'bata', 'symbol': 'bta', 'name': 'Bata'},
#  {'id': 'deutsche-emark', 'symbol': 'dem', 'name': 'Deutsche eMark'},
#  {'id': 'okcash', 'symbol': 'ok', 'name': 'OKCash'},
#  {'id': 'marinecoin', 'symbol': 'mtc', 'name': 'Marinecoin'},
#  {'id': 'ethereum', 'symbol': 'eth', 'name': 'Ethereum'},
#  {'id': 'transfercoin', 'symbol': 'tx', 'name': 'Transfercoin'},
#  {'id': 'nyancoin', 'symbol': 'nyan', 'name': 'Nyancoin'},
#  {'id': 'hexx', 'symbol': 'hxx', 'name': 'HexxCoin'},
#  {'id': 'bitzeny', 'symbol': 'zny', 'name': 'BitZeny'},
#  {'id': 'ratecoin', 'symbol': 'xra', 'name': 'Ratecoin'},
#  {'id': 'teslacoin', 'symbol': 'tes', 'name': 'Teslacoin'},
#  {'id': 'siacoin', 'symbol': 'sc', 'name': 'Siacoin'},
#  {'id': 'cryptokenz', 'symbol': 'cyt', 'name': 'Cryptokenz'},
#  {'id': 'trustplus', 'symbol': 'trust', 'name': 'TrustPlus'},
#  {'id': 'mooncoin', 'symbol': 'moon', 'name': 'Mooncoin'},
#  {'id': 'dopecoin', 'symbol': 'dope', 'name': 'DopeCoin'},
#  {'id': 'bitcoin-scrypt', 'symbol': 'btcs', 'name': 'Bitcoin Scrypt'},
#  {'id': 'augur', 'symbol': 'rep', 'name': 'Augur'},
#  {'id': 'factom', 'symbol': 'fct', 'name': 'Factom'},
#  {'id': 'influxcoin', 'symbol': 'infx', 'name': 'Influxcoin'},
#  {'id': 'mapcoin', 'symbol': 'mapc', 'name': 'MapCoin'},
#  {'id': 'swing', 'symbol': 'swing', 'name': 'Swing'},
#  {'id': 'metal-music-coin', 'symbol': 'mtlmc3', 'name': 'Metal Music Coin'},
#  {'id': 'bitcrystals', 'symbol': 'bcy', 'name': 'BitCrystals'},
#  {'id': 'amsterdamcoin', 'symbol': 'ams', 'name': 'AmsterdamCoin'},
#  {'id': 'synereo', 'symbol': 'amp', 'name': 'Synereo'},
#  {'id': 'aeon', 'symbol': 'aeon', 'name': 'Aeon'},
#  {'id': 'sativacoin', 'symbol': 'stv', 'name': 'Sativacoin'},
#  {'id': 'global-currency-reserve',
#   'symbol': 'gcr',
#   'name': 'Global Currency Reserve'},
#  {'id': 'tether', 'symbol': 'usdt', 'name': 'Tether'},
#  {'id': 'obits', 'symbol': 'obits', 'name': 'OBITS'},
#  {'id': 'capricoin', 'symbol': 'cpc', 'name': 'Capricoin'},
#  {'id': 'crown', 'symbol': 'crw', 'name': 'Crown'},
#  {'id': 'decred', 'symbol': 'dcr', 'name': 'Decred'},
#  {'id': 'radium', 'symbol': 'rads', 'name': 'Radium'},
#  {'id': 'expanse', 'symbol': 'exp', 'name': 'Expanse'},
#  {'id': 'moin', 'symbol': 'moin', 'name': 'Moin'},
#  {'id': 'yocoin', 'symbol': 'yoc', 'name': 'Yocoin'},
#  {'id': 'muse', 'symbol': 'xsd', 'name': 'SounDAC'},
#  {'id': 'boostcoin', 'symbol': 'bost', 'name': 'BoostCoin'},
#  {'id': 'woodcoin', 'symbol': 'log', 'name': 'Woodcoin'},
#  {'id': 'canada-ecoin', 'symbol': 'cdn', 'name': 'Canada eCoin'},
#  {'id': 'granitecoin', 'symbol': 'grn', 'name': 'GraniteCoin'},
#  {'id': 'salus', 'symbol': 'sls', 'name': 'SaluS'},
#  {'id': 'bitcoin-ultra', 'symbol': 'btcu', 'name': 'BitcoinUltra'},
#  {'id': 'bitgem', 'symbol': 'btg', 'name': 'Bitgem'},
#  {'id': 'creditbit', 'symbol': 'crb', 'name': 'Creditbit'},
#  {'id': 'gcn-coin', 'symbol': 'gcn', 'name': 'GCN Coin'},
#  {'id': 'lisk', 'symbol': 'lsk', 'name': 'Lisk'},
#  {'id': 'revolutionvr', 'symbol': 'rvr', 'name': 'RevolutionVR'},
#  {'id': 'digixdao', 'symbol': 'dgd', 'name': 'DigixDAO'},
#  {'id': 'steem', 'symbol': 'steem', 'name': 'Steem'},
#  {'id': 'agoras', 'symbol': 'agrs', 'name': 'Agoras Tauchain'},
#  {'id': 'clubcoin', 'symbol': 'club', 'name': 'Clubcoin'},
#  {'id': 'sibcoin', 'symbol': 'sib', 'name': 'SIBCoin'},
#  {'id': 'adzcoin', 'symbol': 'adz', 'name': 'Adzcoin'},
#  {'id': 'safe-exchange-coin', 'symbol': 'safex', 'name': 'Safe Exchange Coin'},
#  {'id': 'leocoin', 'symbol': 'leo', 'name': 'LEOcoin'},
#  {'id': 'waves', 'symbol': 'waves', 'name': 'Waves'},
#  {'id': 'shift', 'symbol': 'shift', 'name': 'Shift'},
#  {'id': 'argentum', 'symbol': 'arg', 'name': 'Argentum'},
#  {'id': 'hodlcoin', 'symbol': 'hodl', 'name': 'HOdlcoin'},
#  {'id': 'sprouts', 'symbol': 'sprts', 'name': 'Sprouts'},
#  {'id': 'unitus', 'symbol': 'uis', 'name': 'Unitus'},
#  {'id': 'edrcoin', 'symbol': 'edrc', 'name': 'EDRCoin'},
#  {'id': 'martexcoin', 'symbol': 'mxt', 'name': 'MarteXcoin'},
#  {'id': 'gamebetcoin', 'symbol': 'gbt', 'name': 'GameBet'},
#  {'id': 'octocoin', 'symbol': '888', 'name': 'Octocoin'},
#  {'id': 'goldblocks', 'symbol': 'gb', 'name': 'GoldBlocks'},
#  {'id': 'rise', 'symbol': 'rise', 'name': 'Rise'},
#  {'id': 'ethereum-classic', 'symbol': 'etc', 'name': 'Ethereum Classic'},
#  {'id': 'trumpcoin', 'symbol': 'trump', 'name': 'Trumpcoin'},
#  {'id': 'xaurum', 'symbol': 'xaur', 'name': 'Xaurum'},
#  {'id': 'hitcoin', 'symbol': 'htc', 'name': 'Hitcoin'},
#  {'id': 'lbry-credits', 'symbol': 'lbc', 'name': 'LBRY Credits'},
#  {'id': 'ion', 'symbol': 'ion', 'name': 'ION'},
#  {'id': 'crevacoin', 'symbol': 'creva', 'name': 'Crevacoin'},
#  {'id': 'unioncoin', 'symbol': 'unc', 'name': 'Unioncoin'},
#  {'id': 'espers', 'symbol': 'esp', 'name': 'Espers'},
#  {'id': 'bitcoin-plus', 'symbol': 'xbc', 'name': 'Bitcoin Plus'},
#  {'id': 'mojocoin', 'symbol': 'mojo', 'name': 'Mojocoin'},
#  {'id': 'zonecoin', 'symbol': 'zne', 'name': 'Zonecoin'},
#  {'id': 'goldmaxcoin', 'symbol': 'gmx', 'name': 'Goldmaxcoin'},
#  {'id': 'zcoin', 'symbol': 'xzc', 'name': 'Zcoin'},
#  {'id': 'neo', 'symbol': 'neo', 'name': 'NEO'},
#  {'id': 'neptunecoin', 'symbol': 'ntc', 'name': 'Neptunecoin'},
#  {'id': 'zcash', 'symbol': 'zec', 'name': 'Zcash'},
#  {'id': 'arcade-token', 'symbol': 'arc', 'name': 'Arcade Token'},
#  {'id': 'singulardtv', 'symbol': 'sngls', 'name': 'SingularDTV'},
#  {'id': 'first-blood', 'symbol': '1st', 'name': 'First Blood'},
#  {'id': 'wexcoin', 'symbol': 'wex', 'name': 'WexCoin'},
#  {'id': 'e-dinar-coin', 'symbol': 'edr', 'name': 'E-Dinar Coin'},
#  {'id': 'ardor', 'symbol': 'ardr', 'name': 'Ardor'},
#  {'id': 'lykke', 'symbol': 'lkk', 'name': 'Lykke'},
#  {'id': 'pipcoin', 'symbol': 'pip', 'name': 'Pipcoin'},
#  {'id': 'iconomi', 'symbol': 'icn', 'name': 'Iconomi'},
#  {'id': 'artex-coin', 'symbol': 'atx', 'name': 'Artex Coin'},
#  {'id': 'stratis', 'symbol': 'strat', 'name': 'Stratis'},
#  {'id': 'openledger', 'symbol': 'icoo', 'name': 'OpenLedger'},
#  {'id': 'jobscoin', 'symbol': 'jobs', 'name': 'Jobscoin'},
#  {'id': 'shilling', 'symbol': 'sh', 'name': 'Shilling'},
#  {'id': 'revolvercoin', 'symbol': 'xre', 'name': 'Revolvercoin'},
#  {'id': 'pesobit', 'symbol': 'psb', 'name': 'Pesobit'},
#  {'id': 'veros', 'symbol': 'vrs', 'name': 'Veros'},
#  {'id': 'zclassic', 'symbol': 'zcl', 'name': 'Zclassic'},
#  {'id': 'peerplays', 'symbol': 'ppy', 'name': 'Peerplays'},
#  {'id': 'golem', 'symbol': 'gnt', 'name': 'Golem'},
#  {'id': 'vslice', 'symbol': 'vsl', 'name': 'vSlice'},
#  {'id': 'spectrecoin', 'symbol': 'xspec', 'name': 'Spectrecoin'},
#  {'id': 'pascalcoin', 'symbol': 'pasc', 'name': 'Pascalcoin'},
#  {'id': 'pivx', 'symbol': 'pivx', 'name': 'PIVX'},
#  {'id': 'cagecoin', 'symbol': 'cage', 'name': 'Cagecoin'},
#  {'id': 'byteball', 'symbol': 'gbyte', 'name': 'Byteball Bytes'},
#  {'id': 'golos', 'symbol': 'golos', 'name': 'Golos'},
#  {'id': 'nexium', 'symbol': 'nxc', 'name': 'Nexium'},
#  {'id': 'lomocoin', 'symbol': 'lmc', 'name': 'LoMoCoin'},
#  {'id': 'heat', 'symbol': 'heat', 'name': 'HEAT'},
#  {'id': 'incent', 'symbol': 'incnt', 'name': 'Incent'},
#  {'id': 'pepecash', 'symbol': 'pepecash', 'name': 'PepeCash'},
#  {'id': 'hacker-gold', 'symbol': 'hkg', 'name': 'Hacker Gold'},
#  {'id': 'veriumreserve', 'symbol': 'vrm', 'name': 'VeriumReserve'},
#  {'id': 'hicoin', 'symbol': 'xhi', 'name': 'HiCoin'},
#  {'id': 'bipcoin', 'symbol': 'bip', 'name': 'BipCoin'},
#  {'id': 'nexus', 'symbol': 'nxs', 'name': 'Nexus'},
#  {'id': 'xenixcoin', 'symbol': 'xen', 'name': 'Xenixcoin'},
#  {'id': 'kashhcoin', 'symbol': 'kashh', 'name': 'Kashhcoin'},
#  {'id': 'belacoin', 'symbol': 'bela', 'name': 'Belacoin'},
#  {'id': 'bitparkcoin', 'symbol': 'bpc', 'name': 'Bitparkcoin'},
#  {'id': 'centurion', 'symbol': 'cnt', 'name': 'Centurion'},
#  {'id': 'gambit', 'symbol': 'gam', 'name': 'Gambit'},
#  {'id': 'foldingcoin', 'symbol': 'fldc', 'name': 'Foldingcoin'},
#  {'id': 'energycoin', 'symbol': 'enrg', 'name': 'Energycoin'},
#  {'id': 'circuits-of-value', 'symbol': 'coval', 'name': 'Circuits of Value'},
#  {'id': 'wild-beast-block', 'symbol': 'wbb', 'name': 'Wild Beast Block'},
#  {'id': 'darcrus', 'symbol': 'dar', 'name': 'Darcrus'},
#  {'id': 'triggers', 'symbol': 'trig', 'name': 'Triggers'},
#  {'id': 'riecoin', 'symbol': 'ric', 'name': 'Riecoin'},
#  {'id': 'zccoin', 'symbol': 'zcc', 'name': 'ZcCoin'},
#  {'id': 'janus', 'symbol': 'jns', 'name': 'Janus'},
#  {'id': 'tao', 'symbol': 'xto', 'name': 'Tao'},
#  {'id': 'synergy', 'symbol': 'snrg', 'name': 'Synergy'},
#  {'id': 'fitcoin', 'symbol': 'fit', 'name': 'Fitcoin'},
#  {'id': 'chronobank', 'symbol': 'time', 'name': 'Chronobank'},
#  {'id': 'melon', 'symbol': 'mln', 'name': 'Melon'},
#  {'id': 'prcoin', 'symbol': 'prc', 'name': 'PRCoin'},
#  {'id': 'pakcoin', 'symbol': 'pak', 'name': 'Pakcoin'},
#  {'id': 'sequence', 'symbol': 'seq', 'name': 'Sequence'},
#  {'id': 'exclusivecoin', 'symbol': 'excl', 'name': 'ExclusiveCoin'},
#  {'id': 'parkbyte', 'symbol': 'pkb', 'name': 'ParkByte'},
#  {'id': 'komodo', 'symbol': 'kmd', 'name': 'Komodo'},
#  {'id': 'bitsend', 'symbol': 'bsd', 'name': 'BitSend'},
#  {'id': 'ark', 'symbol': 'ark', 'name': 'Ark'},
#  {'id': 'thegcccoin', 'symbol': 'gcc', 'name': 'Global Cryptocurrency'},
#  {'id': 'first-bitcoin', 'symbol': 'bit', 'name': 'First Bitcoin'},
#  {'id': 'mbitbooks', 'symbol': 'mbit', 'name': 'MBitBooks'},
#  {'id': 'round', 'symbol': 'round', 'name': 'Round'},
#  {'id': 'utacoin', 'symbol': 'uta', 'name': 'UtaCoin'},
#  {'id': 'lepen', 'symbol': 'lepen', 'name': 'LePen'},
#  {'id': 'yashcoin', 'symbol': 'yash', 'name': 'YashCoin'},
#  {'id': 'swarm-city', 'symbol': 'swt', 'name': 'Swarm City'},
#  {'id': 'musicoin', 'symbol': 'music', 'name': 'Musicoin'},
#  {'id': 'truckcoin', 'symbol': 'trk', 'name': 'Truckcoin'},
#  {'id': 'breakout', 'symbol': 'brk', 'name': 'Breakout'},
#  {'id': 'breakout-stake', 'symbol': 'brx', 'name': 'Breakout Stake'},
#  {'id': 'bankcoin', 'symbol': 'b@', 'name': 'Bankcoin'},
#  {'id': 'audiocoin', 'symbol': 'adc', 'name': 'AudioCoin'},
#  {'id': 'dubaicoin-dbix', 'symbol': 'dbix', 'name': 'DubaiCoin-DBIX'},
#  {'id': 'solarflarecoin', 'symbol': 'sfc', 'name': 'SolarFlareCoin'},
#  {'id': 'arcticcoin', 'symbol': 'arc', 'name': 'ArcticCoin'},
#  {'id': 'edgeless', 'symbol': 'edg', 'name': 'Edgeless'},
#  {'id': 'asch', 'symbol': 'xas', 'name': 'Asch'},
#  {'id': 'master-swiscoin', 'symbol': 'mscn', 'name': 'Master Swiscoin'},
#  {'id': 'coin2-1', 'symbol': 'c2', 'name': 'Coin2.1'},
#  {'id': 'tattoocoin-limited',
#   'symbol': 'tle',
#   'name': 'Tattoocoin (Limited Edition)'},
#  {'id': 'torcoin', 'symbol': 'tor', 'name': 'Torcoin'},
#  {'id': 'xtrabytes', 'symbol': 'xby', 'name': 'XtraBYtes'},
#  {'id': 'wetrust', 'symbol': 'trst', 'name': 'WeTrust'},
#  {'id': 'iexec-rlc', 'symbol': 'rlc', 'name': 'iExec RLC'},
#  {'id': 'humaniq', 'symbol': 'hmq', 'name': 'Humaniq'},
#  {'id': 'wings', 'symbol': 'wings', 'name': 'Wings'},
#  {'id': 'joincoin', 'symbol': 'j', 'name': 'Joincoin'},
#  {'id': 'britcoin', 'symbol': 'brit', 'name': 'Britcoin'},
#  {'id': 'steem-dollars', 'symbol': 'sbd', 'name': 'Steem Dollars'},
#  {'id': 'qwark', 'symbol': 'qwark', 'name': 'Qwark'},
#  {'id': 'insanecoin', 'symbol': 'insn', 'name': 'INSaNe'},
#  {'id': 'luckchain', 'symbol': 'bash', 'name': 'LuckChain'},
#  {'id': 'visio', 'symbol': 'visio', 'name': 'Visio'},
#  {'id': 'geocoin', 'symbol': 'geo', 'name': 'Geocoin'},
#  {'id': 'cryptocarbon', 'symbol': 'ccrb', 'name': 'CryptoCarbon'},
#  {'id': 'gnosis', 'symbol': 'gno', 'name': 'Gnosis'},
#  {'id': 'evergreencoin', 'symbol': 'egc', 'name': 'EverGreenCoin'},
#  {'id': 'tagcoin', 'symbol': 'tag', 'name': 'Tagcoin'},
#  {'id': 'renos', 'symbol': 'rns', 'name': 'Renos'},
#  {'id': '2give', 'symbol': '2give', 'name': '2GIVE'},
#  {'id': 'korecoin', 'symbol': 'kore', 'name': 'KoreCoin'},
#  {'id': 'dotcoin', 'symbol': 'dot', 'name': 'Dotcoin'},
#  {'id': 'smartcoin', 'symbol': 'smc', 'name': 'Smartcoin'},
#  {'id': 'kushcoin', 'symbol': 'kush', 'name': 'Kushcoin'},
#  {'id': 'chaincoin', 'symbol': 'chc', 'name': 'Chaincoin'},
#  {'id': 'bitCNY', 'symbol': 'bitcny', 'name': 'bitCNY'},
#  {'id': 'prizm', 'symbol': 'pzm', 'name': 'Prizm'},
#  {'id': 'tokencard', 'symbol': 'tkn', 'name': 'TokenCard'},
#  {'id': 'kurrent', 'symbol': 'kurt', 'name': 'Kurrent'},
#  {'id': 'basic-attention-token',
#   'symbol': 'bat',
#   'name': 'Basic Attention Token'},
#  {'id': 'bcap', 'symbol': 'bcap', 'name': 'BCAP'},
#  {'id': 'machinecoin', 'symbol': 'mac', 'name': 'Machinecoin'},
#  {'id': 'bitcore', 'symbol': 'btx', 'name': 'Bitcore'},
#  {'id': 'aragon', 'symbol': 'ant', 'name': 'Aragon'},
#  {'id': 'creativecoin', 'symbol': 'crea', 'name': 'CREA'},
#  {'id': 'matchpool', 'symbol': 'gup', 'name': 'Guppy'},
#  {'id': 'qtum', 'symbol': 'qtum', 'name': 'Qtum'},
#  {'id': 'smileycoin', 'symbol': 'smly', 'name': 'Smileycoin'},
#  {'id': '1337', 'symbol': '1337', 'name': '1337'},
#  {'id': 'skycoin', 'symbol': 'sky', 'name': 'Skycoin'},
#  {'id': 'electra', 'symbol': 'eca', 'name': 'Electra'},
#  {'id': 'moneta', 'symbol': 'moneta', 'name': 'Moneta'},
#  {'id': 'zencash', 'symbol': 'zen', 'name': 'Horizen'},
#  {'id': 'iota', 'symbol': 'miota', 'name': 'IOTA'},
#  {'id': 'newyorkcoin', 'symbol': 'nyc', 'name': 'NewYorkCoin'},
#  {'id': 'pesetacoin', 'symbol': 'ptc', 'name': 'Pesetacoin'},
#  {'id': 'veritaseum', 'symbol': 'veri', 'name': 'Veritaseum'},
#  {'id': 'avoncoin', 'symbol': 'acn', 'name': 'Avoncoin'},
#  {'id': 'dynamic', 'symbol': 'dyn', 'name': 'Dynamic'},
#  {'id': 'syndicate', 'symbol': 'synx', 'name': 'Syndicate'},
#  {'id': 'zrcoin', 'symbol': 'zrc', 'name': 'ZrCoin'},
#  {'id': 'quantum-resistant-ledger',
#   'symbol': 'qrl',
#   'name': 'Quantum Resistant Ledger'},
#  {'id': 'hush', 'symbol': 'hush', 'name': 'Hush'},
#  {'id': 'minereum', 'symbol': 'mne', 'name': 'Minereum'},
#  {'id': 'lunyr', 'symbol': 'lun', 'name': 'Lunyr'},
#  {'id': 'bancor', 'symbol': 'bnt', 'name': 'Bancor Network Token'},
#  {'id': 'ecobit', 'symbol': 'ecob', 'name': 'Ecobit'},
#  {'id': 'eos', 'symbol': 'eos', 'name': 'EOS'},
#  {'id': 'monaco', 'symbol': 'mco', 'name': 'Crypto.com'},
#  {'id': 'tyrocoin', 'symbol': 'tyc', 'name': 'Tyrocoin'},
#  {'id': 'legends-room', 'symbol': 'more', 'name': 'Legends Room'},
#  {'id': 'internet-of-people', 'symbol': 'iop', 'name': 'Internet of People'},
#  {'id': 'ecc', 'symbol': 'ecc', 'name': 'ECC'},
#  {'id': 'xp', 'symbol': 'xp', 'name': 'XP'},
#  {'id': 'patientory', 'symbol': 'ptoy', 'name': 'Patientory'},
#  {'id': 'mcap', 'symbol': 'mcap', 'name': 'MCAP'},
#  {'id': 'dinastycoin', 'symbol': 'dcy', 'name': 'Dinastycoin'},
#  {'id': 'voise', 'symbol': 'voise', 'name': 'VOISE'},
#  {'id': 'sakuracoin', 'symbol': 'skr', 'name': 'Sakuracoin'},
#  {'id': 'soarcoin', 'symbol': 'soar', 'name': 'Soarcoin'},
#  {'id': 'numeraire', 'symbol': 'nmr', 'name': 'Numeraire'},
#  {'id': 'populous', 'symbol': 'ppt', 'name': 'Populous'},
#  {'id': 'decent', 'symbol': 'dct', 'name': 'Decent'},
#  {'id': 'theresa-may-coin', 'symbol': 'may', 'name': 'Theresa May Coin'},
#  {'id': 'nano', 'symbol': 'nano', 'name': 'Nano'},
#  {'id': 'mysterium', 'symbol': 'myst', 'name': 'Mysterium'},
#  {'id': 'nolimitcoin', 'symbol': 'nlc2', 'name': 'NoLimitCoin'},
#  {'id': 'wagerr', 'symbol': 'wgr', 'name': 'Wagerr'},
#  {'id': 'denarius', 'symbol': 'dnr', 'name': 'Denarius'},
#  {'id': 'funfair', 'symbol': 'fun', 'name': 'FunFair'},
#  {'id': 'cofound-it', 'symbol': 'cfi', 'name': 'Cofound.it'},
#  {'id': 'metal', 'symbol': 'mtl', 'name': 'Metal'},
#  {'id': 'flash', 'symbol': 'flash', 'name': 'Flash'},
#  {'id': 'polybius', 'symbol': 'plbt', 'name': 'Polybius'},
#  {'id': 'procurrency', 'symbol': 'proc', 'name': 'ProCurrency'},
#  {'id': 'mobilego', 'symbol': 'mgo', 'name': 'MobileGo'},
#  {'id': 'triangles', 'symbol': 'tri', 'name': 'Triangles'},
#  {'id': 'cryptoping', 'symbol': 'ping', 'name': 'CryptoPing'},
#  {'id': 'geertcoin', 'symbol': 'geert', 'name': 'GeertCoin'},
#  {'id': 'putincoin', 'symbol': 'put', 'name': 'PutinCoin'},
#  {'id': 'tenx', 'symbol': 'pay', 'name': 'TenX'},
#  {'id': 'omisego', 'symbol': 'omg', 'name': 'OmiseGo'},
#  {'id': 'useless-ethereum-token',
#   'symbol': 'uet',
#   'name': 'Useless Ethereum Token'},
#  {'id': 'adtoken', 'symbol': 'adt', 'name': 'adToken'},
#  {'id': 'status', 'symbol': 'SNT', 'name': 'Status'},
#  {'id': 'bitcoin-cash', 'symbol': 'bch', 'name': 'Bitcoin Cash'},
#  {'id': 'embers', 'symbol': 'mbrs', 'name': 'Embers'},
#  {'id': 'linda', 'symbol': 'linda', 'name': 'Linda'},
#  {'id': 'rialto', 'symbol': 'xrl', 'name': 'Rialto'},
#  {'id': 'mantracoin', 'symbol': 'mnc', 'name': 'MantraCoin'},
#  {'id': 'operacoin', 'symbol': 'ocn', 'name': 'Operacoin'},
#  {'id': 'peepcoin', 'symbol': 'pcn', 'name': 'Peepcoin'},
#  {'id': 'joulecoin', 'symbol': 'xjo', 'name': 'Joulecoin'},
#  {'id': 'civic', 'symbol': 'cvc', 'name': 'Civic'},
#  {'id': 'dhg', 'symbol': 'dhg', 'name': 'DHG'},
#  {'id': 'link-platform', 'symbol': 'lnk', 'name': 'Link Platform'},
#  {'id': 'starta', 'symbol': 'sta', 'name': 'Starta'},
#  {'id': 'bit20', 'symbol': 'btwty', 'name': 'Bit20'},
#  {'id': 'ethos', 'symbol': 'ethos', 'name': 'Ethos'},
#  {'id': 'terranova', 'symbol': 'ter', 'name': 'TerraNova'},
#  {'id': 'sovereign-hero', 'symbol': 'hero', 'name': 'Sovereign Hero'},
#  {'id': 'santiment-network-token',
#   'symbol': 'san',
#   'name': 'Santiment Network Token'},
#  {'id': 'global-tour-coin', 'symbol': 'gtc', 'name': 'Global Tour Coin'},
#  {'id': 'rupee', 'symbol': 'rup', 'name': 'Rupee'},
#  {'id': 'futurxe', 'symbol': 'fxe', 'name': 'FuturXe'},
#  {'id': 'daxxcoin', 'symbol': 'daxx', 'name': 'Daxxcoin'},
#  {'id': 'falcoin', 'symbol': 'fal', 'name': 'Falcoin'},
#  {'id': 'sphre-air', 'symbol': 'xid', 'name': 'Sphre AIR'},
#  {'id': 'gulfcoin', 'symbol': 'mgc', 'name': 'MyGulfCoin'},
#  {'id': 'paccoin', 'symbol': '$pac', 'name': 'PACcoin'},
#  {'id': 'pillar', 'symbol': 'plr', 'name': 'Pillar'},
#  {'id': 'elastic', 'symbol': 'xel', 'name': 'Elastic'},
#  {'id': 'peoplecoin', 'symbol': 'men', 'name': 'PeopleCoin'},
#  {'id': 'rhfcoin', 'symbol': 'rhfc', 'name': 'RHFCoin'},
#  {'id': 'insurex', 'symbol': 'ixt', 'name': 'iXledger'},
#  {'id': 'mothership', 'symbol': 'msp', 'name': 'Mothership'},
#  {'id': 'geysercoin', 'symbol': 'gsr', 'name': 'GeyserCoin'},
#  {'id': 'embercoin', 'symbol': 'emb', 'name': 'EmberCoin'},
#  {'id': 'campuscoin', 'symbol': 'cmpco', 'name': 'CampusCoin'},
#  {'id': '300token', 'symbol': '300', 'name': '300 Token'},
#  {'id': 'primalbase', 'symbol': 'pbt', 'name': 'Primalbase'},
#  {'id': 'toacoin', 'symbol': 'toa', 'name': 'ToaCoin'},
#  {'id': 'binancecoin', 'symbol': 'bnb', 'name': 'Binance Coin'},
#  {'id': 'oraclechain', 'symbol': 'oct', 'name': 'OracleChain'},
#  {'id': 'coimatic-2', 'symbol': 'ctic2', 'name': 'Coimatic 2.0'},
#  {'id': 'royalties', 'symbol': 'xry', 'name': 'Royalties'},
#  {'id': 'harmonycoin', 'symbol': 'hmc', 'name': 'HarmonyCoin'},
#  {'id': 'skincoin', 'symbol': 'skin', 'name': 'SkinCoin'},
#  {'id': 'das', 'symbol': 'das', 'name': 'DAS'},
#  {'id': 'smartcash', 'symbol': 'smart', 'name': 'SmartCash'},
#  {'id': 'primulon', 'symbol': 'primu', 'name': 'Primulon'},
#  {'id': 'particl', 'symbol': 'part', 'name': 'Particl'},
#  {'id': 'litebitcoin', 'symbol': 'lbtc', 'name': 'LiteBitcoin'},
#  {'id': 'rsgpcoin', 'symbol': 'rsgp', 'name': 'RSGPcoin'},
#  {'id': 'catcoin', 'symbol': 'cat', 'name': 'Catcoin'},
#  {'id': 'adex', 'symbol': 'adx', 'name': 'AdEx'},
#  {'id': 'indorse', 'symbol': 'ind', 'name': 'Indorse'},
#  {'id': 'district0x', 'symbol': 'dnt', 'name': 'district0x'},
#  {'id': 'dentacoin', 'symbol': 'dcn', 'name': 'Dentacoin'},
#  {'id': 'openanx', 'symbol': 'oax', 'name': 'OpenANX'},
#  {'id': 'incakoin', 'symbol': 'nka', 'name': 'IncaKoin'},
#  {'id': 'eternity', 'symbol': 'ent', 'name': 'Eternity'},
#  {'id': 'cryptoforecast', 'symbol': 'cft', 'name': 'CryptoForecast'},
#  {'id': 'gas', 'symbol': 'gas', 'name': 'Gas'},
#  {'id': 'stronghands', 'symbol': 'shnd', 'name': 'StrongHands'},
#  {'id': 'dimecoin', 'symbol': 'dime', 'name': 'Dimecoin'},
#  {'id': 'sonm', 'symbol': 'snm', 'name': 'SONM'},
#  {'id': 'cvcoin', 'symbol': 'cvn', 'name': 'CVCoin'},
#  {'id': '0x', 'symbol': 'zrx', 'name': '0x'},
#  {'id': 'nimiq', 'symbol': 'net', 'name': 'Nimiq Exchange Token'},
#  {'id': 'hempcoin-thc', 'symbol': 'thc', 'name': 'Hempcoin'},
#  {'id': 'the-cypherfunks', 'symbol': 'funk', 'name': 'The Cypherfunks'},
#  {'id': 'cypher', 'symbol': 'cyr', 'name': 'Cypher'},
#  {'id': 'adshares', 'symbol': 'adst', 'name': 'AdShares'},
#  {'id': 'propy', 'symbol': 'pro', 'name': 'Propy'},
#  {'id': 'morningstar', 'symbol': 'mrng', 'name': 'MorningStar'},
#  {'id': 'iquant', 'symbol': 'iqt', 'name': 'iQuant'},
#  {'id': 'atbcoin', 'symbol': 'atb', 'name': 'ATBCoin'},
#  {'id': 'sociall', 'symbol': 'scl', 'name': 'Sociall'},
#  {'id': 'xpa', 'symbol': 'xpa', 'name': 'XPA'},
#  {'id': 'blackmoon-crypto', 'symbol': 'bmc', 'name': 'Blackmoon Crypto'},
#  {'id': 'chainlink', 'symbol': 'link', 'name': 'ChainLink'},
#  {'id': 'decentraland', 'symbol': 'mana', 'name': 'Decentraland'},
#  {'id': 'bowhead-health', 'symbol': 'aht', 'name': 'Bowhead Health'},
#  {'id': 'droxne', 'symbol': 'drxne', 'name': 'DROXNE'},
#  {'id': 'credo', 'symbol': 'credo', 'name': 'Credo'},
#  {'id': 'buzzcoin', 'symbol': 'buzz', 'name': 'BuzzCoin'},
#  {'id': 'rex', 'symbol': 'rex', 'name': 'Imbrex'},
#  {'id': 'neurodao', 'symbol': 'ndao', 'name': 'NeuroDAO'},
#  {'id': 'oceanlab', 'symbol': 'ocl', 'name': 'Oceanlab'},
#  {'id': 'wallet-builders-coin',
#   'symbol': 'wbc',
#   'name': 'Wallet Builders Coin'},
#  {'id': 'vivo', 'symbol': 'vivo', 'name': 'VIVO'},
#  {'id': 'neblio', 'symbol': 'nebl', 'name': 'Neblio'},
#  {'id': 'moeda-loyalty-points',
#   'symbol': 'mda',
#   'name': 'Moeda Loyalty Points'},
#  {'id': 'facecoin', 'symbol': 'fc', 'name': 'Facecoin'},
#  {'id': 'magnetcoin', 'symbol': 'magn', 'name': 'Magnetcoin'},
#  {'id': 'vsync', 'symbol': 'vsx', 'name': 'Vsync'},
#  {'id': 'hive', 'symbol': 'hvn', 'name': 'Hiveterminal token'},
#  {'id': 'agrello', 'symbol': 'dlt', 'name': 'Agrello'},
#  {'id': 'aventus', 'symbol': 'avt', 'name': 'Aventus'},
#  {'id': 'monetha', 'symbol': 'mth', 'name': 'Monetha'},
#  {'id': 'masternodecoin', 'symbol': 'mtnc', 'name': 'Masternodecoin'},
#  {'id': 'cyder', 'symbol': 'cyder', 'name': 'Cyder'},
#  {'id': 'kronecoin', 'symbol': 'krone', 'name': 'Kronecoin'},
#  {'id': 'starcredits', 'symbol': 'strc', 'name': 'StarCredits'},
#  {'id': 'giga-watt-token', 'symbol': 'wtt', 'name': 'Giga Watt Token'},
#  {'id': 'blockchain-index', 'symbol': 'blx', 'name': 'Blockchain Index'},
#  {'id': 'poet', 'symbol': 'poe', 'name': 'Po.et'},
#  {'id': 'lltoken', 'symbol': 'llt', 'name': 'LLToken'},
#  {'id': 'litecoin-ultra', 'symbol': 'ltcu', 'name': 'LiteCoin Ultra'},
#  {'id': 'loopring', 'symbol': 'lrc', 'name': 'Loopring'},
#  {'id': 'suretly', 'symbol': 'sur', 'name': 'Suretly'},
#  {'id': 'opus', 'symbol': 'opt', 'name': 'Opus'},
#  {'id': 'primas', 'symbol': 'pst', 'name': 'Primas'},
#  {'id': 'eot-token', 'symbol': 'eot', 'name': 'EOT'},
#  {'id': 'ulatech', 'symbol': 'ula', 'name': 'Ulatech'},
#  {'id': 'brother', 'symbol': 'brat', 'name': 'BROTHER'},
#  {'id': 'tierion', 'symbol': 'tnt', 'name': 'Tierion'},
#  {'id': 'monacocoin', 'symbol': 'xmcc', 'name': 'Monoeci'},
#  {'id': 'sigmacoin', 'symbol': 'sigma', 'name': 'SIGMAcoin'},
#  {'id': 'namocoin', 'symbol': 'namo', 'name': 'NamoCoin'},
#  {'id': 'bitqy', 'symbol': 'bq', 'name': 'bitqy'},
#  {'id': 'biblepay', 'symbol': 'bbp', 'name': 'BiblePay'},
#  {'id': 'adcoin', 'symbol': 'acc', 'name': 'AdCoin'},
#  {'id': 'oxfina', 'symbol': 'ox', 'name': 'OX Fina'},
#  {'id': 'protean', 'symbol': 'prn', 'name': 'Proteania'},
#  {'id': 'dalecoin', 'symbol': 'dalc', 'name': 'Dalecoin'},
#  {'id': 'atmcoin', 'symbol': 'atmc', 'name': 'ATMCoin'},
#  {'id': 'xtdcoin', 'symbol': 'xtd', 'name': 'XTD Coin'},
#  {'id': 'frazcoin', 'symbol': 'fraz', 'name': 'Frazcoin'},
#  {'id': 'trueflip', 'symbol': 'tfl', 'name': 'TrueFlip'},
#  {'id': 'dfscoin', 'symbol': 'dfs', 'name': 'DFSCoin'},
#  {'id': 'wicoin', 'symbol': 'wic', 'name': 'Wi Coin'},
#  {'id': 'elixir', 'symbol': 'elix', 'name': 'Elixir'},
#  {'id': 'billionaire-token', 'symbol': 'xbl', 'name': 'Billionaire Token'},
#  {'id': 'kyber-network', 'symbol': 'knc', 'name': 'Kyber Network'},
#  {'id': 'vibe', 'symbol': 'vibe', 'name': 'VIBE'},
#  {'id': 'storj', 'symbol': 'storj', 'name': 'Storj'},
#  {'id': 'substratum', 'symbol': 'sub', 'name': 'Substratum'},
#  {'id': 'chronologic', 'symbol': 'day', 'name': 'Chronologic'},
#  {'id': 'crypto-insight', 'symbol': 'tkr', 'name': 'CryptoInsight'},
#  {'id': 'lampix', 'symbol': 'pix', 'name': 'Lampix'},
#  {'id': 'coss', 'symbol': 'coss', 'name': 'COSS'},
#  {'id': 'bitdice', 'symbol': 'csno', 'name': 'BitDice'},
#  {'id': 'rivetz', 'symbol': 'rvt', 'name': 'Rivetz'},
#  {'id': 'kin', 'symbol': 'kin', 'name': 'Kin'},
#  {'id': 'interzone', 'symbol': 'itz', 'name': 'Interzone'},
#  {'id': 'targetcoin', 'symbol': 'tgt', 'name': 'Target Coin'},
#  {'id': 'salt', 'symbol': 'salt', 'name': 'SALT'},
#  {'id': 'indiacoin', 'symbol': 'india', 'name': 'India Coin'},
#  {'id': 'ormeuscoin', 'symbol': 'orme', 'name': 'Ormeus Coin'},
#  {'id': 'kolion', 'symbol': 'kln', 'name': 'Kolion'},
#  {'id': 'colossuscoinxt', 'symbol': 'colx', 'name': 'ColossusXT'},
#  {'id': 'trezarcoin', 'symbol': 'tzc', 'name': 'TrezarCoin'},
#  {'id': 'smart-investment-fund-token',
#   'symbol': 'sift',
#   'name': 'Smart Investment Fund Token'},
#  {'id': 'hodlbucks', 'symbol': 'hdlb', 'name': 'HODL Bucks'},
#  {'id': 'obsidian', 'symbol': 'odn', 'name': 'Obsidian'},
#  {'id': 'cobinhood', 'symbol': 'cob', 'name': 'Cobinhood'},
#  {'id': 'regalcoin', 'symbol': 'rec', 'name': 'Regalcoin'},
#  {'id': 'msd', 'symbol': 'msd', 'name': 'MSD'},
#  {'id': 'bismuth', 'symbol': 'bis', 'name': 'Bismuth'},
#  {'id': 'cardano', 'symbol': 'ada', 'name': 'Cardano'},
#  {'id': 'tezos', 'symbol': 'xtz', 'name': 'Tezos'},
#  {'id': 'infinity-economics', 'symbol': 'xin', 'name': 'Infinity Economics'},
#  {'id': 'ebitcoin', 'symbol': 'ebtc', 'name': 'eBitcoin'},
#  {'id': 'macro', 'symbol': 'mcr', 'name': 'Macro'},
#  {'id': 'kickico', 'symbol': 'kick', 'name': 'KickCoin'},
#  {'id': 'encryptotel-eth', 'symbol': 'ett', 'name': 'EncryptoTel [Waves]'},
#  {'id': 'viberate', 'symbol': 'vib', 'name': 'Viberate'},
#  {'id': 'rchain', 'symbol': 'rhoc', 'name': 'RChain'},
#  {'id': 'internxt', 'symbol': 'inxt', 'name': 'Internxt'},
#  {'id': 'prospectors-gold', 'symbol': 'pgl', 'name': 'Prospectors Gold'},
#  {'id': 'whalecoin', 'symbol': 'whl', 'name': 'WhaleCoin'},
#  {'id': 'flik', 'symbol': 'flik', 'name': 'FLiK'},
#  {'id': 'ethbet', 'symbol': 'ebet', 'name': 'EthBet'},
#  {'id': 'sandcoin', 'symbol': 'snd', 'name': 'Sandcoin'},
#  {'id': 'wild-crypto', 'symbol': 'wild', 'name': 'Wild Crypto'},
#  {'id': 'real', 'symbol': 'real', 'name': 'Real Estate Asset Ledger'},
#  {'id': 'hubii-network', 'symbol': 'hbt', 'name': 'Hubii Network'},
#  {'id': 'crystal-clear', 'symbol': 'cct', 'name': 'Crystal Clear'},
#  {'id': 'bridgecoin', 'symbol': 'bco', 'name': 'BridgeCoin'},
#  {'id': 'everex', 'symbol': 'evx', 'name': 'Everex'},
#  {'id': 'eltc', 'symbol': 'eltc2', 'name': 'eLTC'},
#  {'id': 'paypie', 'symbol': 'ppp', 'name': 'PayPie'},
#  {'id': 'airtoken', 'symbol': 'air', 'name': 'AirToken'},
#  {'id': 'postoken', 'symbol': 'pos', 'name': 'PoSToken'},
#  {'id': 'senderon', 'symbol': 'sdrn', 'name': 'Senderon'},
#  {'id': 'alis', 'symbol': 'alis', 'name': 'ALIS'},
#  {'id': 'bitcoinz', 'symbol': 'btcz', 'name': 'BitcoinZ'},
#  {'id': 'hellogold', 'symbol': 'hgt', 'name': 'HelloGold'},
#  {'id': 'cindicator', 'symbol': 'cnd', 'name': 'Cindicator'},
#  {'id': 'enigma', 'symbol': 'eng', 'name': 'Enigma'},
#  {'id': 'bastonet', 'symbol': 'bsn', 'name': 'Bastonet'},
#  {'id': 'zeusshield', 'symbol': 'zsc', 'name': 'Zeusshield'},
#  {'id': 'ethereum-cash', 'symbol': 'ecash', 'name': 'Ethereum Cash'},
#  {'id': 'corion', 'symbol': 'cor', 'name': 'Corion Platform'},
#  {'id': 'authorship', 'symbol': 'ats', 'name': 'Authorship'},
#  {'id': 'etherdoge', 'symbol': 'edoge', 'name': 'EtherDoge'},
#  {'id': 'royal-kingdom-coin', 'symbol': 'rkc', 'name': 'Royal Kingdom Coin'},
#  {'id': 'akuyacoin', 'symbol': 'aky', 'name': 'Akuya Coin'},
#  {'id': 'exchangen', 'symbol': 'exn', 'name': 'ExchangeN'},
#  {'id': 'piplcoin', 'symbol': 'pipl', 'name': 'PiplCoin'},
#  {'id': 'eidoo', 'symbol': 'edo', 'name': 'Eidoo'},
#  {'id': 'airswap', 'symbol': 'ast', 'name': 'AirSwap'},
#  {'id': 'bitsoar', 'symbol': 'bsr', 'name': 'BitSoar'},
#  {'id': 'change', 'symbol': 'cag', 'name': 'Change'},
#  {'id': 'blockmason-credit-protocol',
#   'symbol': 'bcpt',
#   'name': 'BlockMason Credit Protocol'},
#  {'id': 'aion', 'symbol': 'aion', 'name': 'Aion'},
#  {'id': 'tracto', 'symbol': 'trct', 'name': 'Tracto'},
#  {'id': 'maecenas', 'symbol': 'art', 'name': 'Maecenas'},
#  {'id': 'everus', 'symbol': 'evr', 'name': 'Everus'},
#  {'id': 'dutchcoin', 'symbol': 'dutch', 'name': 'Dutch Coin'},
#  {'id': 'swapcoin', 'symbol': 'swp', 'name': 'Swapcoin'},
#  {'id': 'domraider', 'symbol': 'drt', 'name': 'DomRaider'},
#  {'id': 'request-network', 'symbol': 'req', 'name': 'Request Network'},
#  {'id': 'segwit2x', 'symbol': 'b2x', 'name': 'SegWit2x'},
#  {'id': 'bitcoincashscrypt', 'symbol': 'bccs', 'name': 'BitcoinCashScrypt'},
#  {'id': 'ethereum-gold', 'symbol': 'etg', 'name': 'Ethereum Gold'},
#  {'id': 'eusd', 'symbol': 'eusd', 'name': 'eUSD'},
#  {'id': 'blue', 'symbol': 'blue', 'name': 'Blue Protocol'},
#  {'id': 'runners', 'symbol': 'runners', 'name': 'Runners'},
#  {'id': 'life', 'symbol': 'life', 'name': 'LIFE'},
#  {'id': 'modum', 'symbol': 'mod', 'name': 'Modum'},
#  {'id': 'amber', 'symbol': 'amb', 'name': 'Ambrosus'},
#  {'id': 'icos', 'symbol': 'icos', 'name': 'ICOS'},
#  {'id': 'bitcoin-gold', 'symbol': 'btg', 'name': 'Bitcoin Gold'},
#  {'id': '10m-token', 'symbol': '10mt', 'name': '10M Token'},
#  {'id': 'litecoin-gold', 'symbol': 'ltg', 'name': 'Litecoin Gold'},
#  {'id': 'kucoin-shares', 'symbol': 'kcs', 'name': 'KuCoin Shares'},
#  {'id': 'open-trading-network',
#   'symbol': 'otn',
#   'name': 'Open Trading Network'},
#  {'id': 'exrnchain', 'symbol': 'exrn', 'name': 'EXRNchain'},
#  {'id': 'clearpoll', 'symbol': 'poll', 'name': 'ClearPoll'},
#  {'id': 'latoken', 'symbol': 'la', 'name': 'LATOKEN'},
#  {'id': 'exchange-union', 'symbol': 'xuc', 'name': 'Exchange Union'},
#  {'id': 'nuls', 'symbol': 'nuls', 'name': 'Nuls'},
#  {'id': 'bitcoin-red', 'symbol': 'btcred', 'name': 'Bitcoin Red'},
#  {'id': 'paragon', 'symbol': 'prg', 'name': 'Paragon'},
#  {'id': 'ripio-credit-network',
#   'symbol': 'rcn',
#   'name': 'Ripio Credit Network'},
#  {'id': 'mercury-protocol', 'symbol': 'gmt', 'name': 'Mercury Protocol'},
#  {'id': 'icon', 'symbol': 'icx', 'name': 'ICON'},
#  {'id': 'javascript-token', 'symbol': 'js', 'name': 'JavaScript Token'},
#  {'id': 'ethereum-lite', 'symbol': 'elite', 'name': 'Ethereum Lite'},
#  {'id': 'bitcoin-silver', 'symbol': 'btcs', 'name': 'Bitcoin Silver'},
#  {'id': 'intelligent-trading-tech',
#   'symbol': 'itt',
#   'name': 'Intelligent Trading Foundation'},
#  {'id': 'iethereum', 'symbol': 'ieth', 'name': 'iEthereum'},
#  {'id': 'pirl', 'symbol': 'pirl', 'name': 'Pirl'},
#  {'id': 'xenon', 'symbol': 'xnn', 'name': 'Xenon'},
#  {'id': 'luxcoin', 'symbol': 'lux', 'name': 'LUXCoin'},
#  {'id': 'ereal', 'symbol': 'ereal', 'name': 'eREAL'},
#  {'id': 'network-token', 'symbol': 'bku', 'name': 'Blocktek University'},
#  {'id': 'dovu', 'symbol': 'dov', 'name': 'Dovu'},
#  {'id': 'cash-poker-pro', 'symbol': 'cash', 'name': 'Cash Poker Pro'},
#  {'id': 'red-pulse', 'symbol': 'phx', 'name': 'Red Pulse Phoenix'},
#  {'id': 'bt1', 'symbol': 'bt1', 'name': 'Bitfinex Bitcoin Future'},
#  {'id': 'bt2', 'symbol': 'bt2', 'name': 'Bitcoin SegWit2X'},
#  {'id': 'playercoin', 'symbol': 'placo', 'name': 'PlayerCoin'},
#  {'id': 'natcoin', 'symbol': 'ntc', 'name': 'Natcoin'},
#  {'id': 'roofs', 'symbol': 'roofs', 'name': 'Roofs'},
#  {'id': 'fapcoin', 'symbol': 'fap', 'name': 'FAPcoin'},
#  {'id': 'btcmoon', 'symbol': 'btcm', 'name': 'BTCMoon'},
#  {'id': 'etherparty', 'symbol': 'fuel', 'name': 'Etherparty'},
#  {'id': 'ellaism', 'symbol': 'ella', 'name': 'Ellaism'},
#  {'id': 'vulcano', 'symbol': 'vulc', 'name': 'Vulcano'},
#  {'id': 'hshare', 'symbol': 'hc', 'name': 'HyperCash'},
#  {'id': 'metaverse-etp', 'symbol': 'etp', 'name': 'Metaverse ETP'},
#  {'id': 'bytom', 'symbol': 'btm', 'name': 'Bytom'},
#  {'id': 'pura', 'symbol': 'pura', 'name': 'Pura'},
#  {'id': 'gxchain', 'symbol': 'gxs', 'name': 'GXChain'},
#  {'id': 'aeternity', 'symbol': 'ae', 'name': 'Aeternity'},
#  {'id': 'bitdeal', 'symbol': 'bdl', 'name': 'Bitdeal'},
#  {'id': 'waltonchain', 'symbol': 'wtc', 'name': 'Waltonchain'},
#  {'id': 'tron', 'symbol': 'trx', 'name': 'TRON'},
#  {'id': 'atmchain', 'symbol': 'atm', 'name': 'ATMChain'},
#  {'id': 'qvolta', 'symbol': 'qvt', 'name': 'Qvolta'},
#  {'id': 'russian-miner-coin', 'symbol': 'rmc', 'name': 'Russian Miner Coin'},
#  {'id': 'flypme', 'symbol': 'fyp', 'name': 'FlypMe'},
#  {'id': 'ethgas', 'symbol': 'egas', 'name': 'ETHGAS'},
#  {'id': 'gimli', 'symbol': 'gim', 'name': 'Gimli'},
#  {'id': 'bitbase', 'symbol': 'btbc', 'name': 'Bitbase'},
#  {'id': 'enjincoin', 'symbol': 'enj', 'name': 'Enjin Coin'},
#  {'id': 'ibtc', 'symbol': 'ibtc', 'name': 'iBTC'},
#  {'id': 'power-ledger', 'symbol': 'powr', 'name': 'Power Ledger'},
#  {'id': 'egold', 'symbol': 'egold', 'name': 'eGold'},
#  {'id': 'grid', 'symbol': 'grid', 'name': 'Grid+'},
#  {'id': 'revain', 'symbol': 'r', 'name': 'Revain'},
#  {'id': 'atlant', 'symbol': 'atl', 'name': 'Atlant'},
#  {'id': 'electroneum', 'symbol': 'etn', 'name': 'Electroneum'},
#  {'id': 'high-gain', 'symbol': 'high', 'name': 'High Gain'},
#  {'id': 'minexcoin', 'symbol': 'mnx', 'name': 'MinexCoin'},
#  {'id': 'altcommunity-coin', 'symbol': 'altom', 'name': 'ALTOM'},
#  {'id': 'ebit', 'symbol': 'ebit', 'name': 'eBIT'},
#  {'id': 'streamr-datacoin', 'symbol': 'data', 'name': 'Streamr DATAcoin'},
#  {'id': 'shield', 'symbol': 'xsh', 'name': 'SHIELD'},
#  {'id': 'eltcoin', 'symbol': 'eltcoin', 'name': 'Eltcoin'},
#  {'id': 'desire', 'symbol': 'dsr', 'name': 'Desire'},
#  {'id': 'unikoin-gold', 'symbol': 'ukg', 'name': 'Unikoin Gold'},
#  {'id': 'autonio', 'symbol': 'nio', 'name': 'Autonio'},
#  {'id': 'cartaxi', 'symbol': 'ctx', 'name': 'CarTaxi'},
#  {'id': 'aeron', 'symbol': 'arn', 'name': 'Aeron'},
#  {'id': 'yellowtoken', 'symbol': 'yel', 'name': 'Yellow Token'},
#  {'id': 'rasputin', 'symbol': 'roc', 'name': 'Rasputin Online Coin'},
#  {'id': 'starcash-network', 'symbol': 'stars', 'name': 'StarCash Network'},
#  {'id': 'phore', 'symbol': 'phr', 'name': 'Phore'},
#  {'id': 'farad', 'symbol': 'frd', 'name': 'Farad'},
#  {'id': 'innova', 'symbol': 'inn', 'name': 'Innova'},
#  {'id': 'raiden-network', 'symbol': 'rdn', 'name': 'Raiden Network Token'},
#  {'id': 'delphy', 'symbol': 'dpy', 'name': 'Delphy'},
#  {'id': 'zephyr', 'symbol': 'zeph', 'name': 'Zephyr'},
#  {'id': 'fujicoin', 'symbol': 'fjc', 'name': 'Fujicoin'},
#  {'id': 'onix', 'symbol': 'onx', 'name': 'Onix'},
#  {'id': 'sumokoin', 'symbol': 'sumo', 'name': 'Sumokoin'},
#  {'id': 'digitalprice', 'symbol': 'dp', 'name': 'DigitalPrice'},
#  {'id': 'memetic', 'symbol': 'meme', 'name': 'Memetic'},
#  {'id': 'dcorp', 'symbol': 'drp', 'name': 'DCORP'},
#  {'id': 'erc20', 'symbol': 'erc20', 'name': 'ERC20'},
#  {'id': 'ties-network', 'symbol': 'tie', 'name': 'Ties.DB'},
#  {'id': 'blockpool', 'symbol': 'bpl', 'name': 'Blockpool'},
#  {'id': 'grimcoin', 'symbol': 'grim', 'name': 'Grimcoin'},
#  {'id': 'zcash-gold', 'symbol': 'zcg', 'name': 'ZCash Gold'},
#  {'id': 'goldpieces', 'symbol': 'gp', 'name': 'GoldPieces'},
#  {'id': 'achain', 'symbol': 'act', 'name': 'Achain'},
#  {'id': 'deeponion', 'symbol': 'onion', 'name': 'DeepOnion'},
#  {'id': 'globaltoken', 'symbol': 'glt', 'name': 'GlobalToken'},
#  {'id': 'eboost', 'symbol': 'ebst', 'name': 'eBoost'},
#  {'id': 'dent', 'symbol': 'dent', 'name': 'Dent'},
#  {'id': 'investfeed', 'symbol': 'ift', 'name': 'InvestFeed'},
#  {'id': 'blockcat', 'symbol': 'cat', 'name': 'BlockCAT'},
#  {'id': 'cream', 'symbol': 'crm', 'name': 'Cream'},
#  {'id': 'bitradio', 'symbol': 'bro', 'name': 'Bitradio'},
#  {'id': 'compcoin', 'symbol': 'cmp', 'name': 'Compcoin'},
#  {'id': 'spacecoin', 'symbol': 'space', 'name': 'Spacecoin'},
#  {'id': 'slevin', 'symbol': 'slevin', 'name': 'Slevin'},
#  {'id': 'oxycoin', 'symbol': 'oxy', 'name': 'Oxycoin'},
#  {'id': 'abjcoin', 'symbol': 'abj', 'name': 'Abjcoin'},
#  {'id': 'emphy', 'symbol': 'epy', 'name': 'Emphy'},
#  {'id': 'neogold', 'symbol': 'neog', 'name': 'NEO GOLD'},
#  {'id': 'decision-token', 'symbol': 'hst', 'name': 'Decision Token'},
#  {'id': 'suncontract', 'symbol': 'snc', 'name': 'SunContract'},
#  {'id': 'vechain', 'symbol': 'vet', 'name': 'VeChain'},
#  {'id': 'decentbet', 'symbol': 'dbet', 'name': 'DecentBet'},
#  {'id': 'sharechain', 'symbol': 'sss', 'name': 'Sharechain'},
#  {'id': 'upfiring', 'symbol': 'ufr', 'name': 'Upfiring'},
#  {'id': 'hawala-today', 'symbol': 'hat', 'name': 'HAT Token'},
#  {'id': 'bitjob', 'symbol': 'stu', 'name': 'bitJob'},
#  {'id': 'genesis-vision', 'symbol': 'gvt', 'name': 'Genesis Vision'},
#  {'id': 'b3coin', 'symbol': 'kb3', 'name': 'B3Coin'},
#  {'id': 'cryptonex', 'symbol': 'cnx', 'name': 'Cryptonex'},
#  {'id': 'eaglecoin', 'symbol': 'eagle', 'name': 'EagleCoin'},
#  {'id': 'ea-coin', 'symbol': 'eag', 'name': 'EA Coin'},
#  {'id': 'privatix', 'symbol': 'prix', 'name': 'Privatix'},
#  {'id': 'intensecoin', 'symbol': 'lthn', 'name': 'Lethean'},
#  {'id': 'pluscoin', 'symbol': 'plcn', 'name': 'PlusCoin'},
#  {'id': 'faceblock', 'symbol': 'fbl', 'name': 'Faceblock'},
#  {'id': 'sisa', 'symbol': 'sisa', 'name': 'SISA'},
#  {'id': 'astro', 'symbol': 'astro', 'name': 'Astro'},
#  {'id': 'paypex', 'symbol': 'payx', 'name': 'Paypex'},
#  {'id': 'ebitcoin-cash', 'symbol': 'ebch', 'name': 'eBitcoin Cash'},
#  {'id': 'gold-reward-token', 'symbol': 'grx', 'name': 'GOLD Reward Token'},
#  {'id': 'bitserial', 'symbol': 'bte', 'name': 'BitSerial'},
#  {'id': 'bitboost', 'symbol': 'bbt', 'name': 'BitBoost'},
#  {'id': 'sugar-exchange', 'symbol': 'sgr', 'name': 'Sugar Exchange'},
#  {'id': 'corethum', 'symbol': 'crtm', 'name': 'Corethum'},
#  {'id': 'bitcloud', 'symbol': 'btdx', 'name': 'Bitcloud'},
#  {'id': 'sphere', 'symbol': 'sphr', 'name': 'Sphere'},
#  {'id': 'europecoin', 'symbol': 'erc', 'name': 'EuropeCoin'},
#  {'id': 'xgox', 'symbol': 'xgox', 'name': 'XGOX'},
#  {'id': 'equitrader', 'symbol': 'eqt', 'name': 'EquiTrader'},
#  {'id': 'neutron', 'symbol': 'ntrn', 'name': 'Neutron'},
#  {'id': 'condensate', 'symbol': 'rain', 'name': 'Condensate'},
#  {'id': 'viuly', 'symbol': 'viu', 'name': 'Viuly'},
#  {'id': 'alqo', 'symbol': 'xlq', 'name': 'ALQO'},
#  {'id': 'gobyte', 'symbol': 'gbx', 'name': 'GoByte'},
#  {'id': 'wincoin', 'symbol': 'wc', 'name': 'WINCOIN'},
#  {'id': 'oyster-pearl', 'symbol': 'prl', 'name': 'Oyster'},
#  {'id': 'infinity-pay', 'symbol': 'ipy', 'name': 'Infinity Pay'},
#  {'id': 'b2b', 'symbol': 'b2b', 'name': 'B2BX'},
#  {'id': 'phantomx', 'symbol': 'pnx', 'name': 'Phantomx'},
#  {'id': 'copico', 'symbol': 'xcpo', 'name': 'Copico'},
#  {'id': 'digipulse', 'symbol': 'dgpt', 'name': 'DigiPulse'},
#  {'id': 'encrypgen', 'symbol': 'dna', 'name': 'EncrypGen'},
#  {'id': 'ink', 'symbol': 'ink', 'name': 'Ink'},
#  {'id': 'bitcoin2x', 'symbol': 'btc2x', 'name': 'Bitcoin2x'},
#  {'id': 'bodhi', 'symbol': 'bot', 'name': 'Bodhi'},
#  {'id': 'quantstamp', 'symbol': 'qsp', 'name': 'Quantstamp'},
#  {'id': 'qash', 'symbol': 'qash', 'name': 'QASH'},
#  {'id': 'zozocoin', 'symbol': 'zzc', 'name': 'ZoZoCoin'},
#  {'id': 'energo', 'symbol': 'tsl', 'name': 'Tesla'},
#  {'id': 'smartbillions', 'symbol': 'PLAY', 'name': 'SmartBillions'},
#  {'id': 'publica', 'symbol': 'pbl', 'name': 'Publica'},
#  {'id': 'magnet', 'symbol': 'mag', 'name': 'Magnet'},
#  {'id': 'spankchain', 'symbol': 'spank', 'name': 'SpankChain'},
#  {'id': 'taas', 'symbol': 'taas', 'name': 'TaaS'},
#  {'id': 'stox', 'symbol': 'stx', 'name': 'Stox'},
#  {'id': 'blox', 'symbol': 'cdt', 'name': 'Blox'},
#  {'id': 'etheroll', 'symbol': 'dice', 'name': 'Etheroll'},
#  {'id': 'blocktix', 'symbol': 'tix', 'name': 'Blocktix'},
#  {'id': 'databits', 'symbol': 'dtb', 'name': 'Databits'},
#  {'id': 'mercury', 'symbol': 'mer', 'name': 'Mercury'},
#  {'id': 'waves-community-token',
#   'symbol': 'wct',
#   'name': 'Waves Community Token'},
#  {'id': 'quantum', 'symbol': 'qau', 'name': 'Quantum'},
#  {'id': 'apx', 'symbol': 'apx', 'name': 'APX'},
#  {'id': 'mybit-token', 'symbol': 'myb', 'name': 'MyBit Token'},
#  {'id': 'pluton', 'symbol': 'plu', 'name': 'Pluton'},
#  {'id': 'atmos', 'symbol': 'atmos', 'name': 'Atmos'},
#  {'id': 'roulettetoken', 'symbol': 'rlt', 'name': 'RouletteToken'},
#  {'id': 'unity-ingot', 'symbol': 'uny', 'name': 'Unity Ingot'},
#  {'id': 'neverdie', 'symbol': 'ndc', 'name': 'NEVERDIE'},
#  {'id': 'adelphoi', 'symbol': 'adl', 'name': 'Adelphoi'},
#  {'id': 'tokes', 'symbol': 'tks', 'name': 'Tokes Platform'},
#  {'id': 'draftcoin', 'symbol': 'dft', 'name': 'DraftCoin'},
#  {'id': 'fund-yourself-now', 'symbol': 'kat', 'name': 'Katalyse'},
#  {'id': 'greencoin', 'symbol': 'gre', 'name': 'Greencoin'},
#  {'id': 'votecoin', 'symbol': 'vot', 'name': 'VoteCoin'},
#  {'id': 'bitcoin-diamond', 'symbol': 'bcd', 'name': 'Bitcoin Diamond'},
#  {'id': 'poly-ai', 'symbol': 'ai', 'name': 'POLY AI'},
#  {'id': 'accelerator-network', 'symbol': 'acc', 'name': 'Accelerator Network'},
#  {'id': 'triaconta', 'symbol': 'tria', 'name': 'Triaconta'},
#  {'id': 'plexcoin', 'symbol': 'plx', 'name': 'PlexCoin'},
#  {'id': 'monkey-project', 'symbol': 'monk', 'name': 'Monkey Project'},
#  {'id': 'flixxo', 'symbol': 'flixx', 'name': 'Flixxo'},
#  {'id': 'glasscoin', 'symbol': 'gls', 'name': 'GlassCoin'},
#  {'id': 'time-new-bank', 'symbol': 'tnb', 'name': 'Time New Bank'},
#  {'id': 'blockv', 'symbol': 'vee', 'name': 'BLOCKv'},
#  {'id': 'mywish', 'symbol': 'wish', 'name': 'MyWish'},
#  {'id': 'eventchain', 'symbol': 'evc', 'name': 'EventChain'},
#  {'id': 'uahpay', 'symbol': 'uah', 'name': 'UAHPay'},
#  {'id': 'yoyow', 'symbol': 'yoyow', 'name': 'YOYOW'},
#  {'id': 'dao-casino', 'symbol': 'bet', 'name': 'DAO.Casino'},
#  {'id': 'universal-currency', 'symbol': 'unit', 'name': 'Universal Currency'},
#  {'id': 'divi', 'symbol': 'divi', 'name': 'Divi'},
#  {'id': 'ethereum-movie-venture',
#   'symbol': 'emv',
#   'name': 'Ethereum Movie Venture'},
#  {'id': 'ethbits', 'symbol': 'etbs', 'name': 'Ethbits'},
#  {'id': 'linx', 'symbol': 'linx', 'name': 'Linx'},
#  {'id': 'elementrem', 'symbol': 'ele', 'name': 'Elementrem'},
#  {'id': 'monster-byte', 'symbol': 'mbi', 'name': 'Monster Byte'},
#  {'id': 'kekcoin', 'symbol': 'kek', 'name': 'KekCoin'},
#  {'id': 'growers-international',
#   'symbol': 'grwi',
#   'name': 'Growers International'},
#  {'id': 'ecocoin', 'symbol': 'eco', 'name': 'EcoCoin'},
#  {'id': '42-coin', 'symbol': '42', 'name': '42-coin'},
#  {'id': 'wavesgo', 'symbol': 'wgo', 'name': 'WavesGo'},
#  {'id': 'unify', 'symbol': 'unify', 'name': 'Unify'},
#  {'id': 'ong-social', 'symbol': 'ong', 'name': 'onG.social'},
#  {'id': 'ccore', 'symbol': 'cco', 'name': 'Ccore'},
#  {'id': 'qbao', 'symbol': 'qbt', 'name': 'Qbao'},
#  {'id': 'dragonchain', 'symbol': 'drgn', 'name': 'Dragonchain'},
#  {'id': 'payfair', 'symbol': 'pfr', 'name': 'Payfair'},
#  {'id': 'carboncoin', 'symbol': 'carbon', 'name': 'Carboncoin'},
#  {'id': 'zero', 'symbol': 'zer', 'name': 'Zero'},
#  {'id': 'solaris', 'symbol': 'xlr', 'name': 'Solaris'},
#  {'id': 'happycoin', 'symbol': 'hpc', 'name': 'Happycoin'},
#  {'id': 'mao-zedong', 'symbol': 'mao', 'name': 'Mao Zedong'},
#  {'id': 'petrodollar', 'symbol': 'xpd', 'name': 'PetroDollar'},
#  {'id': 'goodomy', 'symbol': 'good', 'name': 'Goodomy'},
#  {'id': 'netko', 'symbol': 'netko', 'name': 'Netko'},
#  {'id': 'presearch', 'symbol': 'pre', 'name': 'Presearch'},
#  {'id': 'cybermiles', 'symbol': 'cmt', 'name': 'CyberMiles'},
#  {'id': 'blockcdn', 'symbol': 'bcdn', 'name': 'BlockCDN'},
#  {'id': 'cappasity', 'symbol': 'capp', 'name': 'Cappasity'},
#  {'id': 'eroscoin', 'symbol': 'ero', 'name': 'Eroscoin'},
#  {'id': 'iot-chain', 'symbol': 'itc', 'name': 'IoT Chain'},
#  {'id': 'jiyo', 'symbol': 'jiyox', 'name': 'Jiyo'},
#  {'id': 'social-send', 'symbol': 'send', 'name': 'Social Send'},
#  {'id': 'nekonium', 'symbol': 'nuko', 'name': 'Nekonium'},
#  {'id': 'firstcoin', 'symbol': 'frst', 'name': 'Firstcoin'},
#  {'id': 'animecoin', 'symbol': 'ani', 'name': 'Animecoin'},
#  {'id': 'magiccoin', 'symbol': 'mage', 'name': 'MagicCoin'},
#  {'id': 'bonpay', 'symbol': 'bon', 'name': 'Bonpay'},
#  {'id': 'bitcurrency', 'symbol': 'bc', 'name': 'Bitcurrency'},
#  {'id': 'newbium', 'symbol': 'newb', 'name': 'Newbium'},
#  {'id': 'kobocoin', 'symbol': 'kobo', 'name': 'Kobocoin'},
#  {'id': 'bitbtc', 'symbol': 'bitbtc', 'name': 'bitBTC'},
#  {'id': 'tychocoin', 'symbol': 'tycho', 'name': 'Tychocoin'},
#  {'id': 'helleniccoin', 'symbol': 'hnc', 'name': 'Hellenic Coin'},
#  {'id': 'bitcoin-fast', 'symbol': 'bcf', 'name': 'Bitcoin Fast'},
#  {'id': 'version', 'symbol': 'v', 'name': 'Version'},
#  {'id': 'bolivarcoin', 'symbol': 'boli', 'name': 'Bolivarcoin'},
#  {'id': 'universe', 'symbol': 'uni', 'name': 'Universe'},
#  {'id': 'snovio', 'symbol': 'snov', 'name': 'Snovian.Space'},
#  {'id': 'strikebitclub', 'symbol': 'sbc', 'name': 'StrikeBitClub'},
#  {'id': 'bulwark', 'symbol': 'bwk', 'name': 'Bulwark'},
#  {'id': 'sagacoin', 'symbol': 'saga', 'name': 'SagaCoin'},
#  {'id': 'tokugawa', 'symbol': 'tok', 'name': 'Tokugawa'},
#  {'id': 'kubera-coin', 'symbol': 'kbr', 'name': 'Kubera Coin'},
#  {'id': 'pioneer-coin', 'symbol': 'pcoin', 'name': 'Pioneer Coin'},
#  {'id': 'advanced-internet-block',
#   'symbol': 'aib',
#   'name': 'Advanced Internet Block'},
#  {'id': 'wabi', 'symbol': 'wabi', 'name': 'WaBi'},
#  {'id': 'crowdcoin', 'symbol': 'crc', 'name': 'CrowdCoin'},
#  {'id': 'sportyco', 'symbol': 'spf', 'name': 'SportyCo'},
#  {'id': 'uquid-coin', 'symbol': 'uqc', 'name': 'Uquid Coin'},
#  {'id': 'medishares', 'symbol': 'mds', 'name': 'MediShares'},
#  {'id': 'prochain', 'symbol': 'pra', 'name': 'ProChain'},
#  {'id': 'ignis', 'symbol': 'ignis', 'name': 'Ignis'},
#  {'id': 'smartmesh', 'symbol': 'smt', 'name': 'SmartMesh'},
#  {'id': 'hollywoodcoin', 'symbol': 'hwc', 'name': 'HollyWoodCoin'},
#  {'id': 'filecoin', 'symbol': 'fil', 'name': 'Filecoin [Futures]'},
#  {'id': 'verify', 'symbol': 'cred', 'name': 'Verify'},
#  {'id': 'musiconomi', 'symbol': 'mci', 'name': 'Musiconomi'},
#  {'id': 'bitcoinx', 'symbol': 'bcx', 'name': 'BitcoinX'},
#  {'id': 'super-bitcoin', 'symbol': 'sbtc', 'name': 'Super Bitcoin'},
#  {'id': 'datum', 'symbol': 'dat', 'name': 'Datum'},
#  {'id': 'trident-group', 'symbol': 'trdt', 'name': 'Trident Group'},
#  {'id': 'micromoney', 'symbol': 'amm', 'name': 'MicroMoney'},
#  {'id': 'lockchain', 'symbol': 'loc', 'name': 'LockTrip'},
#  {'id': 'worldcore', 'symbol': 'wrc', 'name': 'Worldcore'},
#  {'id': 'gifto', 'symbol': 'gto', 'name': 'Gifto'},
#  {'id': 'yenten', 'symbol': 'ytn', 'name': 'YENTEN'},
#  {'id': 'genaro-network', 'symbol': 'gnx', 'name': 'Genaro Network'},
#  {'id': 'united-bitcoin', 'symbol': 'ubtc', 'name': 'United Bitcoin'},
#  {'id': 'maker', 'symbol': 'mkr', 'name': 'Maker'},
#  {'id': 'ethlend', 'symbol': 'lend', 'name': 'ETHLend'},
#  {'id': 'universalroyalcoin', 'symbol': 'unrc', 'name': 'UniversalRoyalCoin'},
#  {'id': 'simple-token', 'symbol': 'ost', 'name': 'OST'},
#  {'id': 'cubits', 'symbol': 'qbt', 'name': 'Cubits'},
#  {'id': 'storm', 'symbol': 'storm', 'name': 'Storm'},
#  {'id': 'dynamic-trading-rights',
#   'symbol': 'dtr',
#   'name': 'Dynamic Trading Rights'},
#  {'id': 'aelf', 'symbol': 'elf', 'name': 'aelf'},
#  {'id': 'wax', 'symbol': 'wax', 'name': 'WAX'},
#  {'id': 'medibloc', 'symbol': 'med', 'name': 'Medibloc'},
#  {'id': 'dew', 'symbol': 'dew', 'name': 'DEW'},
#  {'id': 'shorty', 'symbol': 'shorty', 'name': 'Shorty'},
#  {'id': 'inflationcoin', 'symbol': 'iflt', 'name': 'InflationCoin'},
#  {'id': 'btctalkcoin', 'symbol': 'talk', 'name': 'BTCtalkcoin'},
#  {'id': 'bittokens', 'symbol': 'bxt', 'name': 'BitTokens'},
#  {'id': 'tigercoin', 'symbol': 'tgc', 'name': 'Tigercoin'},
#  {'id': 'bolenum', 'symbol': 'bln', 'name': 'Bolenum'},
#  {'id': 'litebar', 'symbol': 'ltb', 'name': 'LiteBar'},
#  {'id': '808coin', 'symbol': '808', 'name': '808Coin'},
#  {'id': 'chancoin', 'symbol': '4chn', 'name': 'ChanCoin'},
#  {'id': 'litecoin-plus', 'symbol': 'lcp', 'name': 'Litecoin Plus'},
#  {'id': 'briacoin', 'symbol': 'bria', 'name': 'BriaCoin'},
#  {'id': 'blakestar', 'symbol': 'blas', 'name': 'BlakeStar'},
#  {'id': 'gapcoin', 'symbol': 'gap', 'name': 'Gapcoin'},
#  {'id': 'postcoin', 'symbol': 'post', 'name': 'PostCoin'},
#  {'id': 'pascal-lite', 'symbol': 'pasl', 'name': 'Pascal Lite'},
#  {'id': 'aricoin', 'symbol': 'ari', 'name': 'Aricoin'},
#  {'id': 'funcoin', 'symbol': 'func', 'name': 'FUNCoin'},
#  {'id': 'kayicoin', 'symbol': 'kayi', 'name': 'Kayicoin'},
#  {'id': 'debitcoin', 'symbol': 'dbtc', 'name': 'Debitcoin'},
#  {'id': 'bitcoin-planet', 'symbol': 'btpl', 'name': 'Bitcoin Planet'},
#  {'id': 'c-bit', 'symbol': 'xct', 'name': 'C-Bit'},
#  {'id': 'securecoin', 'symbol': 'src', 'name': 'SecureCoin'},
#  {'id': 'scorecoin', 'symbol': 'score', 'name': 'Scorecoin'},
#  {'id': 'anarchistsprime', 'symbol': 'acp', 'name': 'AnarchistsPrime'},
#  {'id': 'ronpaulcoin', 'symbol': 'rpc', 'name': 'RonPaulCoin'},
#  {'id': 'coinonatx', 'symbol': 'xcxt', 'name': 'CoinonatX'},
#  {'id': 'tajcoin', 'symbol': 'taj', 'name': 'TajCoin'},
#  {'id': 'nevacoin', 'symbol': 'neva', 'name': 'NevaCoin'},
#  {'id': 'reecoin', 'symbol': 'ree', 'name': 'ReeCoin'},
#  {'id': 'mustangcoin', 'symbol': 'mst', 'name': 'MustangCoin'},
#  {'id': 'allsafe', 'symbol': 'asafe2', 'name': 'AllSafe'},
#  {'id': 'womencoin', 'symbol': 'women', 'name': 'WomenCoin'},
#  {'id': 'printerium', 'symbol': 'prx', 'name': 'Printerium'},
#  {'id': 'eryllium', 'symbol': 'ery', 'name': 'Eryllium'},
#  {'id': 'osmiumcoin', 'symbol': 'os76', 'name': 'OsmiumCoin'},
#  {'id': 'vaperscoin', 'symbol': 'vprc', 'name': 'VapersCoin'},
#  {'id': 'rawcoin', 'symbol': 'xrc', 'name': 'Rawcoin'},
#  {'id': 'levoplus', 'symbol': 'lvps', 'name': 'LevoPlus'},
#  {'id': 'project-x', 'symbol': 'nanox', 'name': 'Project-X'},
#  {'id': 'russiacoin', 'symbol': 'rc', 'name': 'RussiaCoin'},
#  {'id': 'naga', 'symbol': 'ngc', 'name': 'NAGA'},
#  {'id': 'bread', 'symbol': 'brd', 'name': 'Bread'},
#  {'id': 'bibox-token', 'symbol': 'bix', 'name': 'Bibox Token'},
#  {'id': 'dai', 'symbol': 'dai', 'name': 'Dai'},
#  {'id': 'sophiatx', 'symbol': 'sphtx', 'name': 'SophiaTX'},
#  {'id': 'bounty0x', 'symbol': 'bnty', 'name': 'Bounty0x'},
#  {'id': 'dimcoin', 'symbol': 'dim', 'name': 'DIMCOIN'},
#  {'id': 'fundrequest', 'symbol': 'fnd', 'name': 'FundRequest'},
#  {'id': 'starbase', 'symbol': 'star', 'name': 'Starbase'},
#  {'id': 'inchain', 'symbol': 'inc', 'name': 'InChain'},
#  {'id': 'napoleon-x', 'symbol': 'npx', 'name': 'Napoleon X'},
#  {'id': 'swishcoin', 'symbol': 'swh', 'name': 'SwishCoin'},
#  {'id': 'hirematch', 'symbol': 'hire', 'name': 'HireMatch'},
#  {'id': 'brickblock', 'symbol': 'bbk', 'name': 'BrickBlock'},
#  {'id': 'sense', 'symbol': 'sense', 'name': 'Sense'},
#  {'id': 'soma', 'symbol': 'sct', 'name': 'Soma'},
#  {'id': 'crypto-improvement-fund',
#   'symbol': 'cif',
#   'name': 'Crypto Improvement Fund'},
#  {'id': 'matryx', 'symbol': 'mtx', 'name': 'MATRYX'},
#  {'id': 'reality-clash', 'symbol': 'rcc', 'name': 'Reality Clash'},
#  {'id': 'mobius', 'symbol': 'mobi', 'name': 'Mobius'},
#  {'id': 'aicoin', 'symbol': 'xai', 'name': 'AICoin'},
#  {'id': 'playmarket', 'symbol': 'pmt', 'name': 'DAO PlayMarket 2.0'},
#  {'id': 'wolk', 'symbol': 'wlk', 'name': 'Wolk'},
#  {'id': 'internet-of-coins', 'symbol': 'xhy', 'name': 'Hybrid'},
#  {'id': 'e-chat', 'symbol': 'echt', 'name': 'e-Chat'},
#  ...]

# %%
df_list = pd.DataFrame(j)
df_list.head(10)
# Out:
#              id          name symbol
# 0       bitcoin       Bitcoin    btc
# 1      litecoin      Litecoin    ltc
# 2    auroracoin    Auroracoin    aur
# 3      peercoin      Peercoin    ppc
# 4      dogecoin      Dogecoin   doge
# 5           nxt           NXT    nxt
# 6          omni          Omni   omni
# 7      namecoin      Namecoin    nmc
# 8  counterparty  Counterparty    xcp
# 9         quark         Quark    qrk

# %% [markdown]
# ## Importing Bitcoin market value for last 10 days, vs. EUR

# %%
# Bitcoin, vs.EUR, 10 Days
# request with explicit paramenters dictionary

url = base + 'coins/bitcoin/market_chart'
param_dict = { 'id':'bitcoin', 'vs_currency':'eur', 'days':10}

result = requests.get(url, params=param_dict)

j = result.json()
df = pd.DataFrame(j['prices'], columns=['time', 'price'])
df.head(10)
# Out:
#             time        price
# 0  1541436271202  5648.650115
# 1  1541439856379  5637.884690
# 2  1541443458450  5629.431744
# 3  1541447049040  5631.059936
# 4  1541450651087  5638.800647
# 5  1541454257519  5643.785242
# 6  1541457852484  5625.436828
# 7  1541461792185  5621.603513
# 8  1541465053657  5624.956032
# 9  1541468654060  5636.878437

# %% [markdown]
# ## Convert time code to time series index

# %%
df = pd.DataFrame(j['prices'], columns=['time', 'price'])
df['time'] = pd.to_datetime(df['time'], unit='ms')

df.set_index('time', inplace=True)
df.head(10)
# Out:
#                                price
# time
# 2018-11-05 16:44:31.202  5648.650115
# 2018-11-05 17:44:16.379  5637.884690
# 2018-11-05 18:44:18.450  5629.431744
# 2018-11-05 19:44:09.040  5631.059936
# 2018-11-05 20:44:11.087  5638.800647
# 2018-11-05 21:44:17.519  5643.785242
# 2018-11-05 22:44:12.484  5625.436828
# 2018-11-05 23:49:52.185  5621.603513
# 2018-11-06 00:44:13.657  5624.956032
# 2018-11-06 01:44:14.060  5636.878437

# %% [markdown]
# ## Simple plot of time series

# %%
df.plot()

# %% [markdown]
# ## Grouping timeseries by daily average price

# %%
df.groupby(pd.Grouper(freq="d")).mean()
# Out:
#                   price
# time
# 2018-11-05  5634.581589
# 2018-11-06  5646.429555
# 2018-11-07  5721.241746
# 2018-11-08  5713.695722
# 2018-11-09  5680.302232
# 2018-11-10  5673.671151
# 2018-11-11  5658.137700
# 2018-11-12  5705.132485
# 2018-11-13  5682.956508
# 2018-11-14  5453.316636
# 2018-11-15  4968.556571
